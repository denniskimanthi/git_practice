# %% [markdown]
# <a href="https://colab.research.google.com/github/denniskimanthi/git_practice/blob/master/DENNIS_KIMANTHI_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Dennis Kimanthi
# * Student pace: self paced / part time / full time: Part time
# * Scheduled project review date/time:28th July 2024
# * Instructor name:Samwel Jane
# * Blog post URL:

# %% [markdown]
# # **PREVIEW OF TOP UPCOMING MOVIES FROM MICROSOFT**

# %% [markdown]
# **Business Problem**
#
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.

# %% [markdown]
# **Project Overview**
#
# Microsoft wishes to venture into original video content production so as to diversify its portfolio.For this to happen Microsoft needs to understand the dynamics of the movie industry, and the films that are currently doing well at the box office. This project seeks to help Microsoft make informed decisions on what movies to create and provide insights into the movie market

# %% [markdown]
# **OBJECTIVES**
#
#
# *   To explore what type of films are currently doing the best
# *   To translate those findings into actionable insights

# %% [markdown]
# # **DATA UNDERSATNDING**

# %% [markdown]
# The analysis used data from different movie sites which are in the folder ZippedData and in csv file format. The Data files include 'title.basic.csv and tmdb.movies.csv files. To proceed with data analysis we first have to understand our dataset, what they contain and data quality

# %%
#import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#first we import our first dataset and name it df_basics
df_basics = pd.read_csv('/content/title.basics.csv')
#Display the first few rows of the dataset
df_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#import our second dataset and name it as df_movies
df_movies = pd.read_csv('/content/tmdb.movies.csv')
#Display the first few rows of the dataset
df_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
#drop column title
df_movies.drop(['title'], axis=1, inplace=True)

# %% [markdown]
# The code below is for importing bom.movie_gross dataset

# %%
#import our third dataset and name it as df_bom
df_bom = pd.read_csv('/content/bom.movie_gross.csv')
#Display the first few rows of the dataset
df_bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# # Merging the three Dataset

# %% [markdown]
# The code below seeks to merge the three datasets into one on the common column "Original title"

# %%
#Merge the dataset on the common column "Original Tile"
merged_data = pd.merge(df_basics, df_movies, on='original_title', how='inner')
#Display the first few rows of the merged dataset
merged_data.head()
# Out:
#       tconst               primary_title              original_title  \
# 0  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 1  tt0112502                     Bigfoot                     Bigfoot
# 2  tt4503112                     Bigfoot                     Bigfoot
# 3  tt9181914                     Bigfoot                     Bigfoot
# 4  tt0249516                  Foodfight!                  Foodfight!
#
#    start_year  runtime_minutes                   genres  Unnamed: 0  \
# 0        2018            122.0                    Drama       24185
# 1        2017              NaN          Horror,Thriller        5872
# 2        2018              NaN            Action,Horror        5872
# 3        2018             86.0         Animation,Family        5872
# 4        2012             91.0  Action,Animation,Comedy        8456
#
#              genre_ids      id original_language  popularity release_date  \
# ...

# %% [markdown]
# The code below is meant to rename the column original_title to title

# %%
merged_data
# Out:
#           tconst                              primary_title  \
# 0      tt0069049                 The Other Side of the Wind
# 1      tt0112502                                    Bigfoot
# 2      tt4503112                                    Bigfoot
# 3      tt9181914                                    Bigfoot
# 4      tt0249516                                 Foodfight!
# ...          ...                                        ...
# 21073  tt9678886                                    Vacancy
# 21074  tt9777830  John Leguizamo's Latin History for Morons
# 21075  tt9814730                                  The Flare
# 21076  tt9862978                                      Terra
# 21077  tt9869514                               Wake Up Call
#
#                                   original_title  start_year  runtime_minutes  \
# 0                     The Other Side of the Wind        2018            122.0
# 1                                        Bigfoot        2017              NaN
# ...

# %%
#drop column primary_title
merged_data.drop(['primary_title'], axis=1, inplace=True)

# %%
#rename column title
merged_data.rename(columns={'original_title': 'title'}, inplace=True)

# %% [markdown]
# The code below is meant for merging df_basics and df_movies to df_bom on title

# %%
#merge df_basics and df_movies to df_bom
merged_data = pd.merge(merged_data, df_bom, on='title', how='inner')
#Display the first few rows of the merged dataset
merged_data.head()
# Out:
#       tconst        title  start_year  runtime_minutes  \
# 0  tt0337692  On the Road        2012            124.0
# 1  tt2404548  On the Road        2011             90.0
# 2  tt3872966  On the Road        2013             87.0
# 3  tt4339118  On the Road        2014             89.0
# 4  tt5389486  On the Road        2015             39.0
#
#                     genres  Unnamed: 0 genre_ids     id original_language  \
# 0  Adventure,Drama,Romance        5350  [12, 18]  83770                en
# 1                    Drama        5350  [12, 18]  83770                en
# 2              Documentary        5350  [12, 18]  83770                en
# 3                    Drama        5350  [12, 18]  83770                en
# 4              Documentary        5350  [12, 18]  83770                en
#
#    popularity release_date  vote_average  vote_count studio  domestic_gross  \
# 0       8.919   2012-12-21           5.6         518    IFC        744000.0
# ...

# %% [markdown]
# # Accessing Information about our Dataset

# %%
#Getting to know more about the dataset by accessing its information
print(merged_data.columns)
# Out:
# Index(['tconst', 'title', 'start_year', 'runtime_minutes', 'genres',
#        'Unnamed: 0', 'genre_ids', 'id', 'original_language', 'popularity',
#        'release_date', 'vote_average', 'vote_count', 'studio',
#        'domestic_gross', 'foreign_gross', 'year'],
#       dtype='object')

# %%
#Checking number of rows and columns
merged_data.shape
# Out:
# (3089, 17)

# %%
print(merged_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3089 entries, 0 to 3088
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             3089 non-null   object
#  1   title              3089 non-null   object
#  2   start_year         3089 non-null   int64
#  3   runtime_minutes    2899 non-null   float64
#  4   genres             3043 non-null   object
#  5   Unnamed: 0         3089 non-null   int64
#  6   genre_ids          3089 non-null   object
#  7   id                 3089 non-null   int64
#  8   original_language  3089 non-null   object
#  9   popularity         3089 non-null   float64
#  10  release_date       3089 non-null   object
#  11  vote_average       3089 non-null   float64
#  12  vote_count         3089 non-null   int64
#  13  studio             3089 non-null   object
#  14  domestic_gross     3060 non-null   float64
#  15  foreign_gross      2054 non-null   object
# ...

# %%
#check for duplicates
merged_data.duplicated().sum()
# Out:
# 0

# %%
#looking at the columns
merged_data.columns
# Out:
# Index(['tconst', 'title', 'start_year', 'runtime_minutes', 'genres',
#        'Unnamed: 0', 'genre_ids', 'id', 'original_language', 'popularity',
#        'release_date', 'vote_average', 'vote_count', 'studio',
#        'domestic_gross', 'foreign_gross', 'year'],
#       dtype='object')

# %%
#checking for missing data
merged_data.isnull().sum()
# Out:
# tconst                  0
# title                   0
# start_year              0
# runtime_minutes       190
# genres                 46
# Unnamed: 0              0
# genre_ids               0
# id                      0
# original_language       0
# popularity              0
# release_date            0
# vote_average            0
# vote_count              0
# studio                  0
# domestic_gross         29
# foreign_gross        1035
# year                    0
# dtype: int64

# %%
merged_data.describe()
# Out:
#         start_year  runtime_minutes    Unnamed: 0             id   popularity  \
# count  3089.000000      2899.000000   3089.000000    3089.000000  3089.000000
# mean   2014.131434       102.044153  12090.175461  224737.986727     9.988657
# std       2.532601        22.369940   7395.940580  140571.478912     7.354920
# min    2010.000000         3.000000      1.000000    1771.000000     0.600000
# 25%    2012.000000        91.000000   5350.000000   81527.000000     5.805000
# 50%    2014.000000       101.000000  11616.000000  239573.000000     8.975000
# 75%    2016.000000       114.000000  17711.000000  339527.000000    12.836000
# max    2020.000000       181.000000  26506.000000  561861.000000    80.773000
#
#        vote_average    vote_count  domestic_gross         year
# count   3089.000000   3089.000000    3.060000e+03  3089.000000
# mean       6.301295   1408.293299    3.899272e+07  2014.176433
# std        1.069089   2407.214851    7.200373e+07     2.412648
# ...

# %% [markdown]
# **Code for Cleaning missing values in column 'domestic_grosss'**

# %%
#Replacing null values
merged_data['domestic_gross'].fillna(merged_data['domestic_gross'].mean(), inplace=True)
#check if missing value has been replaced
merged_data['domestic_gross'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Code for cleaning missing values in column 'foreign_gross'**

# %%
# Convert 'foreign_gross_x' to numeric, coercing errors to NaN
merged_data['foreign_gross'] = pd.to_numeric(merged_data['foreign_gross'], errors='coerce')

# Now fill missing values with the mean
merged_data['foreign_gross'].fillna(merged_data['foreign_gross'].mean(), inplace=True)

# Check if missing values have been replaced
merged_data['foreign_gross'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Code for cleaning missing values in column 'runtime_minutes'**

# %%
#replacing null values in column 'runtime_minutes'
merged_data['runtime_minutes'].fillna(merged_data['runtime_minutes'].mean(), inplace=True)

#check if missing value has been replaced
merged_data['runtime_minutes'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Code for cleaning values in column "genres"**

# %%
#replacing null values in column genres
merged_data['genres'].fillna(merged_data['genres'].mode()[0], inplace=True)

#check if missing value has been replaced
merged_data['genres'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Dropping columns**
#
# The code below drops the column "original_language"

# %% [markdown]
# The code below seeks to drop the column title since theres already a column named Original_language in the dataset

# %%
#Dropping column 'original_language
merged_data.drop(['original_language'], axis=1, inplace=True)

# %% [markdown]
# The code below seeks to drop the column 'Primary_tilte

# %%
# this code is for dropping 'release_date' column
merged_data.drop(['release_date'], axis=1, inplace=True)

# %% [markdown]
# The code below seeks to drop the column name 'vote_count'

# %%
#this code is for dropping the 'vote_count' column
merged_data.drop(['vote_count'], axis=1, inplace=True)

# %% [markdown]
# The code below seeks to drop column name studio

# %%
# this code drops the column name studio
merged_data.drop(['studio'], axis=1, inplace=True)

# %% [markdown]
# The code below drops the column name year

# %%
#Dropping the column name primary_title
merged_data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# The code below drops the column studio

# %% [markdown]
# The code below drops the column year

# %%
#dropping the column name id
merged_data.drop(['id'], axis=1, inplace=True)

# %%
merged_data.columns
# Out:
# Index(['tconst', 'title', 'start_year', 'runtime_minutes', 'genres',
#        'genre_ids', 'popularity', 'vote_average', 'domestic_gross',
#        'foreign_gross', 'year'],
#       dtype='object')

# %% [markdown]
# **RENAMING COLUMNS**

# %%
#Lets rename "start_year" in df_basics to "year" in df_movies
df_movies.rename(columns={'start_year': 'year'}, inplace=True)

# %% [markdown]
# The code below seeks to rename the column name original_title to Title

# %%
#rename column original_title to title
merged_data.rename(columns={'original_title': 'title'}, inplace=True)

# %% [markdown]
# The code below seeks to rename the column name popularity to popularity_rating

# %%
merged_data.rename(columns={'popularity': 'popularity_rating'}, inplace=True)

# %% [markdown]
# The code below seeks to rename the column name vote_average to vote_average_rating

# %%
merged_data.rename(columns={'vote_average': 'vote_average rating'}, inplace=True)
merged_data
# Out:
#          tconst                    title  start_year  runtime_minutes  \
# 0     tt0337692              On the Road        2012       124.000000
# 1     tt2404548              On the Road        2011        90.000000
# 2     tt3872966              On the Road        2013        87.000000
# 3     tt4339118              On the Road        2014        89.000000
# 4     tt5389486              On the Road        2015        39.000000
# ...         ...                      ...         ...              ...
# 3084  tt8878922  They Shall Not Grow Old        2018        47.000000
# 3085  tt8083476                    Chloe        2017         6.000000
# 3086  tt8097306            Nobody's Fool        2018       110.000000
# 3087  tt8802728                The Witch        2018       102.044153
# 3088  tt8802728                The Witch        2018       102.044153
#
#                              genres        genre_ids  popularity  \
# ...

# %%
#Exporting the cleaned dataset
merged_data.to_csv('merged_data.csv', index=False)

# %%
df = pd.read_csv('/content/merged_data.csv')
df
# Out:
#          tconst                    title  start_year  runtime_minutes  \
# 0     tt0337692              On the Road        2012       124.000000
# 1     tt2404548              On the Road        2011        90.000000
# 2     tt3872966              On the Road        2013        87.000000
# 3     tt4339118              On the Road        2014        89.000000
# 4     tt5389486              On the Road        2015        39.000000
# ...         ...                      ...         ...              ...
# 3084  tt8878922  They Shall Not Grow Old        2018        47.000000
# 3085  tt8083476                    Chloe        2017         6.000000
# 3086  tt8097306            Nobody's Fool        2018       110.000000
# 3087  tt8802728                The Witch        2018       102.044153
# 3088  tt8802728                The Witch        2018       102.044153
#
#                              genres        genre_ids  popularity  \
# ...

# %% [markdown]
# # **DATA ANALYSIS**
#
# Here we are going to explore our data and use visualizations in plenty as we attempt to find answers to our Objectives

# %%
#Display columns
merged_data.columns
# Out:
# Index(['tconst', 'title', 'start_year', 'runtime_minutes', 'genres',
#        'genre_ids', 'popularity', 'vote_average rating', 'domestic_gross',
#        'foreign_gross', 'year'],
#       dtype='object')

# %% [markdown]
# # **VISUALIZATION**

# %% [markdown]
# **IDENTIFYING THE MOST POPULAR MOVIE GENRE IN THE DATA**

# %%
#define a variable that returns value counts of the genres
genre_counts = merged_data['genres'].value_counts()
genre_counts.head(10)
# Out:
# genres
# Drama                         369
# Documentary                   153
# Comedy,Drama,Romance          126
# Comedy,Drama                  108
# Comedy                         93
# Drama,Romance                  80
# Adventure,Animation,Comedy     78
# Drama,Thriller                 64
# Horror                         62
# Comedy,Romance                 53
# Name: count, dtype: int64

# %% [markdown]
# **Visualizing the most popular movie genre**

# %%
#display bar graph of popular movie genre
#display top 10 popular movie genres
top_genres = genre_counts.head(10)
# Plotting
plt.figure(figsize=(10, 6))  # Adjust the figure size
plt.bar(x=top_genres.index, height=top_genres.values, color='skyblue')

# Adding titles and labels
plt.title('Popular Movie Genres')
plt.xlabel('Genres')
plt.ylabel('Distribution')

# Display the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better appearance
plt.show()

# %% [markdown]
# From the bar graph above we see that the most popular movie genre is Drama,followed by Documentary then Horror and so forth

# %% [markdown]
# **VISUALIZING THE VOTE_AVERAGE DISTRIBUTION**

# %% [markdown]
# The code below is meant to visualize the Vote_average of all genres across the dataset

# %%
#Display a variable that returns value counts of Vote_average
vote_average = merged_data['vote_average rating'].value_counts()
vote_average.head(10)
# Out:
# vote_average rating
# 5.8    182
# 6.0    171
# 6.2    158
# 5.9    156
# 6.6    142
# 6.8    136
# 6.1    135
# 6.7    133
# 6.5    113
# 6.3    112
# Name: count, dtype: int64

# %% [markdown]
# Now we plot the above values into a bar graph

# %%
#create a variable 'vote_rating in our data
vote_rating = merged_data['vote_average rating']
#Create histogram graph
plt.figure(figsize=(10, 6))
plt.hist(vote_rating, bins=10, edgecolor='black')

# Add titles and labels
plt.title('Vote average Distribution')
plt.xlabel('Vote average rating')
plt.ylabel('Distribution')

# Display the plot
plt.show()

# %% [markdown]
# From the visualization above we notice that the graph is skewed to the right meaning that most viewers voted for high rated movies and few voted for low rated movies. This means that most viewers preferd to watch high rated films

# %%
merged_data
# Out:
#          tconst                    title  start_year  runtime_minutes  \
# 0     tt0337692              On the Road        2012       124.000000
# 1     tt2404548              On the Road        2011        90.000000
# 2     tt3872966              On the Road        2013        87.000000
# 3     tt4339118              On the Road        2014        89.000000
# 4     tt5389486              On the Road        2015        39.000000
# ...         ...                      ...         ...              ...
# 3084  tt8878922  They Shall Not Grow Old        2018        47.000000
# 3085  tt8083476                    Chloe        2017         6.000000
# 3086  tt8097306            Nobody's Fool        2018       110.000000
# 3087  tt8802728                The Witch        2018       102.044153
# 3088  tt8802728                The Witch        2018       102.044153
#
#                              genres        genre_ids  popularity  \
# ...

# %% [markdown]
#  **GENRE WITH HIGHEST DOMESTIC GROSS**
#
# The code below is meant to show the genre with the highest domestic gross

# %%
#display genre with the highest domestic gross
merged_data.groupby('genres')['domestic_gross'].mean().sort_values(ascending=False)
# Out:
# genres
# Adventure,Drama,Sport       4.007000e+08
# Documentary,Drama,Sport     2.753500e+08
# Action,Adventure,Sci-Fi     2.344489e+08
# Adventure,Drama,Sci-Fi      2.149333e+08
# Adventure,Fantasy           1.929000e+08
#                                 ...
# Documentary,History,News    1.320000e+04
# Action,Adventure            8.500000e+03
# Comedy,Crime,Mystery        5.000000e+03
# Comedy,Thriller             8.000000e+02
# Animation,Drama             6.000000e+02
# Name: domestic_gross, Length: 285, dtype: float64

# %%
#create code that displays genres and domestic gross in descending order with new variable genre_domestic_gross
genre_domestic_gross = merged_data.groupby('genres')['domestic_gross'].mean().sort_values(ascending=False)
genre_domestic_gross.head(10)
# Out:
# genres
# Adventure,Drama,Sport       4.007000e+08
# Documentary,Drama,Sport     2.753500e+08
# Action,Adventure,Sci-Fi     2.344489e+08
# Adventure,Drama,Sci-Fi      2.149333e+08
# Adventure,Fantasy           1.929000e+08
# Biography,Drama,Musical     1.743000e+08
# Sci-Fi                      1.659794e+08
# Animation,Comedy,Family     1.636574e+08
# Action,Adventure,Comedy     1.560047e+08
# Action,Adventure,Mystery    1.509000e+08
# Name: domestic_gross, dtype: float64

# %% [markdown]
# From the above code we see that 'Adventure,Animation and Comedy have the higest revenue domestically

# %% [markdown]
# **Visualize using Bar Graphs**

# %%
# Create a bar plot that displays genres with highest domestic gross
top_genres = genre_counts.head(12)
plt.subplots(figsize=(9, 6))
sns.barplot(x=top_genres.index, y=top_genres.values)
#set x, y and title label
plt.title('Top 10 Genres with Highest Domestic Gross')
plt.xlabel('Genres')
plt.ylabel('Domestic Gross_y')
plt.xticks(rotation=45, ha ='right')
plt.show()

# %% [markdown]
# The Graph above clearly shows that Drama has the highest Domestic gross locally followed by Documentary then Comedy,Drama,Romance

# %% [markdown]
#  **GENRE WITH THE HIGHEST FOREIGN GROSS**
#
#  The code below is meant to show the genre with the highest foreign gross

# %%
#display genre with highest foreign gross internationally
merged_data.groupby('genres')['foreign_gross'].mean().sort_values(ascending=False)
# Out:
# genres
# Adventure,Drama,Sport             8.757000e+08
# Adventure,Fantasy                 5.111333e+08
# Adventure,Drama,Sci-Fi            4.309333e+08
# Action,Adventure,Sci-Fi           3.504504e+08
# Animation,Documentary             3.367000e+08
#                                       ...
# Comedy,Mystery,Romance            4.210000e+05
# Animation,Drama,Sci-Fi            3.180000e+05
# Thriller,Western                  3.000000e+05
# Documentary,Drama,Mystery         2.420000e+05
# Biography,Documentary,Thriller    2.020000e+05
# Name: foreign_gross, Length: 285, dtype: float64

# %%
#create code that displays genres and Foreign gross in descending order with new variable genre_foreign_gross
genre_foreign_gross = merged_data.groupby('genres')['domestic_gross'].mean().sort_values(ascending=False)
genre_foreign_gross.head(10)
# Out:
# genres
# Adventure,Drama,Sport       4.007000e+08
# Documentary,Drama,Sport     2.753500e+08
# Action,Adventure,Sci-Fi     2.344489e+08
# Adventure,Drama,Sci-Fi      2.149333e+08
# Adventure,Fantasy           1.929000e+08
# Biography,Drama,Musical     1.743000e+08
# Sci-Fi                      1.659794e+08
# Animation,Comedy,Family     1.636574e+08
# Action,Adventure,Comedy     1.560047e+08
# Action,Adventure,Mystery    1.509000e+08
# Name: domestic_gross, dtype: float64

# %% [markdown]
# From the above code we see that in the Foreign Market,Adventure,Drama and Sports films have the highest Gross

# %% [markdown]
# **Visualize using Bar Graphs**

# %%
#  Create a bar plot that displays genres with highest domestic gross
genre_foreign_gross = genre_foreign_gross.head(12)
plt.subplots(figsize=(9, 6))
sns.barplot(x=genre_foreign_gross.index, y=genre_foreign_gross)
#set x, y and title label
plt.title('Top 10 Genres with Highest Foreign Gross')
plt.xlabel('Genres')
plt.ylabel('Foreign Gross_y')
plt.xticks(rotation=45, ha ='right')
plt.show()

# %% [markdown]
# The graph above shows that Adventure,Drama and Sport films have the highest Foreign Gross internationally comapred to the rest of the Films

# %% [markdown]
# # **CONCLUSION**
#
# From the data above we clearly see that Drama is the most popular genre followed by Documentary. When we look at the vote average rating, the graph represented is skewed to the right meaning that most viewers voted for high rated movies compared to the few that voted fo the low rated films
# -When we look at the films that had the highest domestic gross locally are Adventure,Darama and Sports while the ones that had the highest foreign gorss internationally are still the same Adventure,Drama and Sports
